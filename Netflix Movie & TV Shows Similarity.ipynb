# %%
import pandas as pd
import pickle
from functools import reduce
import json
import requests
from bs4 import BeautifulSoup
import pickle

# %%
# load the data
df = pd.read_csv('./data/netflix_titles.csv')
# convert to datetime
df["date_added"] = pd.to_datetime(df['date_added'])
df['year'] = df['date_added'].dt.year
df['month'] = df['date_added'].dt.month
df['day'] = df['date_added'].dt.day
# convert columns "director, listed_in, cast and country" in columns that contain a real list
# the strip function is applied on the elements
# if the value is NaN, the new column contains a empty list []
df['directors'] = df['director'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
df['categories'] = df['listed_in'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
df['actors'] = df['cast'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
df['countries'] = df['country'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])

df = df.reset_index()
df.head()
# Out:
#    index   show_id     type                                    title  \
# 0      0  81145628    Movie  Norm of the North: King Sized Adventure
# 1      1  80117401    Movie               Jandino: Whatever it Takes
# 2      2  70234439  TV Show                       Transformers Prime
# 3      3  80058654  TV Show         Transformers: Robots in Disguise
# 4      4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country date_added  release_year  \
# 0  United States, India, South Korea, China 2019-09-09          2019
# 1                            United Kingdom 2016-09-09          2016
# 2                             United States 2018-09-08          2013
# 3                             United States 2018-09-08          2016
# 4                             United States 2017-09-08          2017
#
#      rating  duration                           listed_in  \
# 0     TV-PG    90 min  Children & Family Movies, Comedies
# 1     TV-MA    94 min                     Stand-Up Comedy
# 2  TV-Y7-FV  1 Season                            Kids' TV
# 3     TV-Y7  1 Season                            Kids' TV
# 4     TV-14    99 min                            Comedies
#
#                                          description    year  month  day  \
# 0  Before planning an awesome wedding for his gra...  2019.0    9.0  9.0
# 1  Jandino Asporaat riffs on the challenges of ra...  2016.0    9.0  9.0
# 2  With the help of three human allies, the Autob...  2018.0    9.0  8.0
# 3  When a prison ship crash unleashes hundreds of...  2018.0    9.0  8.0
# 4  When nerdy high schooler Dani finally attracts...  2017.0    9.0  8.0
#
#                     directors                            categories  \
# 0  [Richard Finn, Tim Maltby]  [Children & Family Movies, Comedies]
# 1                          []                     [Stand-Up Comedy]
# 2                          []                            [Kids' TV]
# 3                          []                            [Kids' TV]
# 4          [Fernando Lebrija]                            [Comedies]
#
#                                               actors  \
# 0  [Alan Marriott, Andrew Toth, Brian Dobson, Col...
# 1                                 [Jandino Asporaat]
# 2  [Peter Cullen, Sumalee Montano, Frank Welker, ...
# 3  [Will Friedle, Darren Criss, Constance Zimmer,...
# 4  [Nesta Cooper, Kate Walsh, John Michael Higgin...
#
#                                     countries
# 0  [United States, India, South Korea, China]
# 1                            [United Kingdom]
# 2                             [United States]
# 3                             [United States]
# 4                             [United States]

# %% [markdown]
# #### Should i only filter the top 3 actors that appear in the credits list?

# %%
for i in df[df['title'] == 'House of Cards'].actors:
    print(i)
# Out:
# ['Kevin Spacey', 'Robin Wright', 'Kate Mara', 'Corey Stoll', 'Sakina Jaffrey', 'Kristen Connolly', 'Constance Zimmer', 'Sebastian Arcelus', 'Nathan Darrow', 'Sandrine Holt', 'Michel Gill', 'Elizabeth Norment', 'Mahershala Ali', 'Reg E. Cathey', 'Molly Parker', 'Derek Cecil', 'Elizabeth Marvel', 'Kim Dickens', 'Lars Mikkelsen', 'Michael Kelly', 'Joel Kinnaman', 'Campbell Scott', 'Patricia Clarkson', 'Neve Campbell']

# %%
for i in df[df['title'] == 'Stranger'].actors:
    print(i)
# Out:
# ['Seung-woo Cho', 'Doona Bae', 'Joon-hyuk Lee', 'Kyeong-yeong Lee', 'Jae-myung Yoo', 'Hye-sun Shin']

# %%
for i in df[df['title'] == 'Inception'].actors:
    print(i)
# Out:
# ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Ellen Page', 'Tom Hardy', 'Ken Watanabe', 'Dileep Rao', 'Cillian Murphy', 'Tom Berenger', 'Marion Cotillard', 'Pete Postlethwaite', 'Michael Caine', 'Lukas Haas']

# %%
for i in df[df['title'] == 'Terrace House: Boys & Girls in the City'].actors:
    print(i)
# Out:
# ['You', 'Reina Triendl', 'Ryota Yamasato', 'Yoshimi Tokui', 'Azusa Babazono', 'Ayumu Mochizuki', 'Kentaro']

# %% [markdown]
# ## Uding TFIDF to find similar movies based on description

# %% [markdown]
# - Filter out keywords that occur only once.
# - Convert every word to its stem so that words such as Dogs and Dog are considered the same.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

stemmer = SnowballStemmer('english')
    
# Build the tfidf matrix with the descriptions
text_content = df['description']
vector = TfidfVectorizer(max_df=0.4,         # drop words that occur in more than X percent of documents
                             min_df=1,      # only use words that appear at least X times
                             stop_words='english', # remove stop words
                             lowercase=True, # Convert everything to lower case 
                             use_idf=True,   # Use idf
                             norm=u'l2',     # Normalization
                             smooth_idf=True # Prevents divide-by-zero errors
                            )
tfidf = vector.fit_transform(text_content)

# %%
cosine_similarities = cosine_similarity(tfidf,tfidf)

# %%
titles = df['title']
indices= pd.Series(df.index, index=df['title'])

def get_recommendations(title, cosine_sim, col):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    movie_indices = [i[0] for i in sim_scores]
    movie_scores = [i[1] for i in sim_scores]
    movies = df.iloc[movie_indices]
    movies['scores'] = movie_scores
    if(col == 'soup'):
        return movies[['index', 'show_id', 'title', 'actors', 'directors', 'categories', 'scores']]
    else:
        return movies[['index', 'show_id', 'title', col, 'scores']]

# %%
df_words = pd.DataFrame(vector.transform(text_content).todense(),
                   columns=vector.get_feature_names(), index=df.index)

# %% [markdown]
# ### Stranger

# %%
get_recommendations('Stranger', cosine_similarities, 'description')
# Out:
# /Users/dianaow/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#       index   show_id                        title  \
# 3959   3959  80144372   Asura: The City of Madness
# 2899   2899  80155863          City of Tiny Lights
# 2079   2079  80222788                Day and Night
# 1700   1700  80121973                    Behzat Ç.
# 4643   4643  81149202                      Why Me?
# 1971   1971  80174617                  Borderliner
# 6033   6033  80142550                    The Break
# 685     685  80992769                  Dark Crimes
# 4543   4543  80218783                       Mantra
# 1773   1773  81053958                  Backdraft 2
# 5521   5521  80208373                       Fallet
# 4970   4970  80243541      Bhavesh Joshi Superhero
# 3623   3623  81045060        Merku Thodarchi Malai
# 1536   1536  60000545                The Interview
# 4240   4240  81213874                Vodka Diaries
# 5479   5479  81039073         Kicko & Super Speedo
# 1555   1555  80180710                  Cinta 100KG
# 779     779  60002273          Along Came a Spider
# 4954   4954  80190984  Cop and a Half: New Recruit
# 421     421  81183570  Home Is Where the Killer Is
# 843     843  81167047                       Tunnel
# 3176   3176  80106139           Suicide (Hitabdut)
# 5308   5308  80158042                 Dear Zindagi
# 3603   3603  70045863          Across the Universe
# 4885   4885  81016196                       Mersal
# 5592   5592  70283260                        Reign
# 6050   6050  80161335  The Frankenstein Chronicles
# 2887   2887  80017021          A Most Violent Year
# 1481   1481  70254351                   Satyagraha
# 5905   5905  80026224                     Aquarius
#
#                                             description    scores
# 3959  Caught between a corrupt mayor and a prosecuto...  0.203110
# 2899  In moody London, a burned-out sleuth sinks int...  0.186154
# 2079  A detective assists with an investigation into...  0.159067
# 1700  An Ankara homicide detective with a dark perso...  0.149908
# 4643  A young prosecutor is assigned a career-making...  0.149633
# 1971  To protect his family, a police detective cove...  0.142091
# 6033  A police detective mourning a painful loss mov...  0.141524
# 685   A detective on a cold murder case discovers th...  0.132677
# 4543  An Indian business owner struggles to keep his...  0.131198
# 1773  In this sequel to the 1991 film, a determined ...  0.128617
# 5521  A Swedish detective and her timid British coll...  0.128251
# 4970  When his best friend is killed for uncovering ...  0.124291
# 3623  In southern India, a laborer's dreams of ownin...  0.117103
# 1536  When a man who's seemingly lost everything is ...  0.115589
# 4240  While investigating a series of murders and th...  0.113590
# 5479  This high-energy animated series follows a gut...  0.111926
# 1555  Two female friends, each with confidence issue...  0.111688
# 779   When a girl is kidnapped from a prestigious pr...  0.110167
# 4954  A world-weary detective is forced to team up w...  0.109512
# 421   Recovering from cancer, a young woman thinks s...  0.108837
# 843   While chasing a serial murderer, a detective e...  0.107202
# 3176  A failed businessman must kill himself to pay ...  0.106728
# 5308  A young cinematographer with a bright professi...  0.106005
# 3603  An American girl and a British lad fall in lov...  0.105931
# 4885  A detective arrests a doctor for crimes target...  0.105398
# 5592  This vivid historical drama series tells of th...  0.104368
# 6050  A detective tracks what seems to be a killer w...  0.103638
# 2887  Abel Morales tries to avoid corruption's easy ...  0.103609
# 1481  In this Bollywood drama, a corporate go-getter...  0.103607
# 5905  Amid the turmoil of 1960s LA, two cops and a p...  0.102341

# %%
df_words.transpose().sort_values(1514, ascending=False).head(10).transpose().loc[1514, :]
# Out:
# gutsy         0.342910
# empathy       0.322635
# feel          0.299304
# prosecutor    0.299304
# ability       0.284709
# tackles       0.281767
# corruption    0.242134
# lost          0.237227
# amid          0.234551
# female        0.233697
# Name: 1514, dtype: float64

# %%
df.loc[1514, :].description
# Out:
# 'With the help of a gutsy female detective, a prosecutor who has lost the ability to feel empathy tackles a murder case amid political corruption.'

# %%
df.loc[3959, :].description
# Out:
# "Caught between a corrupt mayor and a prosecutor intent on exposing political depravity, a police detective must decide whose side he's on."

# %% [markdown]
# ### Narcos

# %%
get_recommendations('Narcos', cosine_similarities, 'description')
# Out:
# /Users/dianaow/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#       index   show_id                                       title  \
# 1583   1583  80100933                               Miss Dynamite
# 4857   4857  80035689                                 El Cartel 2
# 1257   1257  80997085                              Narcos: Mexico
# 5939   5939  80133042                                    El Chapo
# 5773   5773  70236561                                     Top Boy
# 5162   5162  80106150                                     Cocaine
# 732     732  81034012                                 Street Flow
# 1480   1480  70303431                              Raja Natwarlal
# 1833   1833  81021631                                  Two Graves
# 3444   3444  80125593                         Historia de un clan
# 485     485  80217066                                  Seis Manos
# 1096   1096  70101696                                    Defiance
# 277     277  80217669                                     Top Boy
# 1768   1768  80047031                    Sin senos no hay paraíso
# 1625   1625  81028570  Extremely Wicked, Shockingly Evil and Vile
# 4599   4599  81037373                             The Sky Is Pink
# 2537   2537  80161640                                I Am Michael
# 3234   3234  81016360                        The Gentleman Driver
# 5781   5781  80221787                                   Bad Blood
# 4194   4194  20077944                                      Ghayal
# 1837   1837  80993495                                        Ajji
# 1754   1754  70073018                     Shootout at Lokhandwala
# 367     367  80178543              FINAL FANTASY XIV Dad of Light
# 1001   1001  80194289                    Gabriel and the Mountain
# 5772   5772  70279656                          The Mind of a Chef
# 5101   5101  80035685                Los tiempos de Pablo Escobar
# 5168   5168  80108473                           La Esclava Blanca
# 687     687  81154549                               Magical Andes
# 793     793  81113890                           Engineering Girls
# 3474   3474  81021294                             When Heroes Fly
#
#                                             description    scores
# 1583  Wealthy, beautiful Valentina falls in love, on...  0.243176
# 4857  Drug trafficker Pepe Cadena navigates the trea...  0.218326
# 1257  Witness the birth of the Mexican drug war in t...  0.202732
# 5939  This drama series chronicles the true story of...  0.189741
# 5773  In this gritty, stylish drama series, two Lond...  0.189012
# 5162  Three films chronicle the cocaine trade's swee...  0.178188
# 732   Three brothers – a gangster, a scholar and an ...  0.162791
# 1480  A small-time con man assembles a team to help ...  0.155327
# 1833  A doctor and a drug addict kidnap the son of a...  0.143659
# 3444  This drama based on a true story follows the P...  0.141224
# 485   Orphans raised by a martial arts master are pl...  0.139081
# 1096  In this action-packed drama based on an extrao...  0.138807
# 277   Two seasoned drug dealers return to the gritty...  0.137034
# 1768  Inspired by a true story, this TV drama shadow...  0.136415
# 1625  Single mother Liz falls for Ted Bundy and refu...  0.128176
# 4599  After succumbing to her terminal illness, a te...  0.127413
# 2537  Gay activist Michael Glatze begins a painful j...  0.123885
# 3234  This documentary follows four tycoons who moon...  0.121836
# 5781  This sprawling crime drama follows the true st...  0.120692
# 4194  Framed for his older brother's murder, a boxer...  0.117306
# 1837  When her small granddaughter is sexually assau...  0.112906
# 1754  Based on a true story, this action film follow...  0.110016
# 367   A father and son rekindle their bond through t...  0.109592
# 1001  In a drama based on a true story, Brazilian ba...  0.107255
# 5772  Producer and narrator Anthony Bourdain explore...  0.105860
# 5101  Featuring never-before-seen images, personal t...  0.104473
# 5168  In Colombia in 1821, a white orphan is taken i...  0.104380
# 687   From Argentina to Colombia, this stunning docu...  0.104268
# 793   Three engineering students deal with dorm dram...  0.101565
# 3474  Years after a bitter falling out, four Israeli...  0.099710

# %%
df_words.transpose().sort_values(5637, ascending=False).head(10).transpose().loc[5637, :]
# Out:
# infamously    0.385197
# fuels         0.355677
# cartels       0.346174
# colombia      0.321142
# gritty        0.308890
# gangster      0.275962
# violent       0.251663
# powerful      0.239644
# drama         0.217334
# drug          0.217334
# Name: 5637, dtype: float64

# %%
df.loc[5637, :].description
# Out:
# "The true story of Colombia's infamously violent and powerful drug cartels fuels this gritty gangster drama series."

# %%
df.loc[1583, :].description
# Out:
# "Wealthy, beautiful Valentina falls in love, only to realize that her man and her family are involved with one of Mexico's most powerful drug cartels."

# %%
df.loc[1257, :].description
# Out:
# 'Witness the birth of the Mexican drug war in the 1980s as a gritty new "Narcos" saga chronicles the true story of the Guadalajara cartel\'s ascent.'

# %% [markdown]
# ### House of Cards

# %%
get_recommendations('House of Cards', cosine_similarities, 'description')
# Out:
# /Users/dianaow/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#       index   show_id
# 5365  A rebellious teen grows up to become one of Mi...  0.123923
# 688   A new breed of secret agents must stop a ruthl...  0.123592
# 1360  A young physician and his beautiful mistress g...  0.118480
# 5257  At odds with his radical instructor's ruthless...  0.114959
# 2793  As Cindy and Dean muddle through their languis...  0.111528
# 3865  Award-winning documentarian Burns profiles thr...  0.108777
# 1799  Finally released after being trapped in an anc...  0.107413
# 5592  This vivid historical drama series tells of th...  0.105741
# 5699  Scottish pensioners Jack and Victor make the m...  0.105646

# %%
df.loc[5741, :].description
# Out:
# 'A ruthless politician will stop at nothing to conquer Washington, D.C., in this Emmy and Golden Globe-winning political drama.'

# %%
df.loc[5789, :].description
# Out:
# "It's the Emmy-winning story of a wealthy family that lost everything, and the one son who had no choice but to keep them all together."

# %%
df.loc[4049, :].description
# Out:
# 'Leonardo DiCaprio crisscrosses the globe to investigate the consequences of man-made globe warming and the measures being taken to reverse it.'

# %% [markdown]
# ### Inception

# %%
get_recommendations('Inception', cosine_similarities, 'description')
# Out:
# /Users/dianaow/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#       index   show_id                              title  \
# 4994   4994  81122206               Til Death Do Us Part
# 1924   1924  70176655                          Apollo 18
# 5875   5875  70264888                       Black Mirror
# 329     329  81154956           Transformers: Cyberverse
# 3939   3939  81067758                          Candyflip
# 1879   1879  80176698                           Abby Sen
# 3891   3891  80097140                     Altered Carbon
# 5892   5892  80100172                               Dark
# 150     150  80124522                             Maniac
# 563     563  70295169                    Hunter's Prayer
# 4315   4315  80988062         Black Mirror: Bandersnatch
# 71       71  80187061                          The Mayor
# 1369   1369    516788                   Forbidden Planet
# 87       87  80200087                             Domino
# 597     597  81025263                       Horror Homes
# 2524   2524  81110498                              ANIMA
# 4360   4360  80225526                     Part-Time Idol
# 1736   1736  70158421                     Action Replayy
# 705     705  80201823                    One Night Stand
# 4693   4693  70236586                               Tezz
# 4252   4252  81032812                        Inst@famous
# 2007   2007  80048568                         London Spy
# 3455   3455  80081960                      Very Big Shot
# 4010   4010  81063160                             Camp X
# 4929   4929  70229041             Tere Naal Love Ho Gaya
# 4250   4250  81045515  Gina Yashere: Laughing to America
# 5296   5296  81035869          A Mission in an Old Movie
# 1810   1810  80057278                     Gabbar Is Back
# 3674   3674  80196138                          Not Alone
# 895     895  81012427       Nature: Animals With Cameras
#
#                                             description    scores
# 4994  Based on the speculative short stories of Mirr...  0.185504
# 1924  This sci-fi thriller suggests that Apollo 17, ...  0.181247
# 5875  This sci-fi anthology series explores a twiste...  0.149816
# 329   Optimus Prime and the AllSpark are missing – a...  0.146768
# 3939  On the incandescent shores of Goa, a young man...  0.146739
# 1879  After losing his seventh job in a row, a TV pr...  0.144639
# 3891  After 250 years on ice, a prisoner returns to ...  0.142263
# 5892  A missing child sets four families on a franti...  0.138113
# 150   Two struggling strangers connect during a mind...  0.135614
# 563   A hired gun has second thoughts when he's cont...  0.127074
# 4315  In 1984, a young programmer begins to question...  0.121755
# 71    With the presidency in mind, the incumbent may...  0.121644
# 1369  A pulp-fiction sci-fi classic, Forbidden Plane...  0.121261
# 87    A Copenhagen police officer hunts for the man ...  0.116382
# 597   Dream homes turn into property nightmares when...  0.109798
# 2524  In a short musical film directed by Paul Thoma...  0.108101
# 4360  After taking a break from the business, a musi...  0.106494
# 1736  Vipul Amrutlal Shah directs this sci-fi rom-co...  0.105248
# 705   An obsession with a woman with whom he had a o...  0.097214
# 4693  This high-octane thriller tells the story of a...  0.093141
# 4252  Self-made social media celebrities share the s...  0.089812
# 2007  When his reclusive-banker lover disappears, a ...  0.085648
# 3455  When three brothers struggling to go straight ...  0.085071
# 4010  Established during World War II, North America...  0.084337
# 4929  Mini isn't eager to wed the rich suitor who's ...  0.081691
# 4250  British comic Gina Yashere takes the stage in ...  0.081309
# 5296  A young man struggles with his overbearing mot...  0.079326
# 1810  After a vengeful college professor targets cor...  0.079290
# 3674  An 18-year-old struggling to understand her be...  0.079141
# 895   With custom-built cameras attached to their bo...  0.078518

# %%
df_words.transpose().sort_values(3524, ascending=False).head(10).transpose().loc[3524, :]
# Out:
# subconscious    0.319833
# entering        0.319833
# mold            0.305496
# espionage       0.275534
# thoughts        0.270812
# fi              0.266647
# sci             0.266647
# bending         0.262922
# built           0.262922
# targets         0.253644
# Name: 3524, dtype: float64

# %%
df.loc[3524, :].description
# Out:
# 'In this mind-bending sci-fi thriller, a man runs an espionage business built around entering the subconscious of his targets to mold their thoughts.'

# %%
df.loc[4994, :].description
# Out:
# 'Based on the speculative short stories of MirrorFiction, this sci-fi thriller anthology plunges headlong into our deepest desires – and darkest fears.'

# %%
df.loc[5875, :].description
# Out:
# "This sci-fi anthology series explores a twisted, high-tech near-future where humanity's greatest innovations and darkest instincts collide."

# %% [markdown]
# ### Using Count Vectorizer to find similar movies based on list of actors, directors, genres combined

# %%
df['actors'] = df['actors'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])
#give high rating to top 3 actors
df['actors'] = df['actors'].apply(lambda x: [val + ',' + val if i<=2 else val for i,val in enumerate(x)])
df['actors'] = df['actors'].apply(lambda x: [val.split(',') for val in x])
df['actors'] = df['actors'].apply(lambda x: [item for sublist in x for item in sublist])
df['actors'] = df['actors'].apply(lambda x: ' '.join(x))

# %%
df['actors'][0]
# Out:
# 'alanmarriott alanmarriott andrewtoth andrewtoth briandobson briandobson colehoward jennifercameron jonathanholmes leetockar lisadurupt mayakay michaeldobson'

# %%
df['directors'] = df['directors'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])
df['directors'] = df['directors'].apply(lambda x: x * 3) #give higher rating to directors
df['directors'] = df['directors'].apply(lambda x: ' '.join(x))

# %%
df['directors'][0]
# Out:
# 'richardfinn timmaltby richardfinn timmaltby richardfinn timmaltby'

# %%
df['categories'] = df['categories'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])
df['categories'] = df['categories'].apply(lambda x: ' '.join(x))

# %%
df['soup'] = df['actors'] + df['directors'] + df['categories']
#df['soup'] = df['soup'].apply(lambda x: ' '.join(x))

# %%
def countVectorizer(col):
    count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
    count_matrix = count.fit_transform(df[col])
    cosine_sim = cosine_similarity(count_matrix, count_matrix)
    return cosine_sim

# %%
cosine_sim = countVectorizer('soup')

# %%
get_recommendations('Okja', cosine_sim, 'soup')
# Out:
# /Users/dianaow/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#       index   show_id
# 3955
# 2997  williameubank willeubank williameubank willeub...
# 5915
# 4872          bassamkurdali bassamkurdali bassamkurdali
# 913           jamesmcteigue jamesmcteigue jamesmcteigue
# 561        donmichaelpaul donmichaelpaul donmichaelpaul
# 1965                         iankirby iankirby iankirby
# 3504                         robcohen robcohen robcohen
# 3255                   peytonreed peytonreed peytonreed
# 1949             terrygilliam terrygilliam terrygilliam
# 5057       louisleterrier louisleterrier louisleterrier
# 5207          jeremiahjones jeremiahjones jeremiahjones
# 2476          mathieuauvray mathieuauvray mathieuauvray
# 4600                   adamalleca adamalleca adamalleca
# 518              ericzaragosa ericzaragosa ericzaragosa
# 825                 bryansinger bryansinger bryansinger
# 1131                   simonwells simonwells simonwells
# 1997                         joemiale joemiale joemiale
# 3045                leetamahori leetamahori leetamahori
# 3086                   robminkoff robminkoff robminkoff
#
#                                              categories    scores
# 1423                    action&adventure sci-fi&fantasy  0.784987
# 1424                    action&adventure sci-fi&fantasy  0.781345
# 5064                    action&adventure sci-fi&fantasy  0.306491
# 2556  action&adventure internationalmovies sci-fi&fa...  0.227921
# 5131                 action&adventure cultmovies dramas  0.209329
# 324                dramas romanticmovies sci-fi&fantasy  0.196760
# 3507                        horrormovies sci-fi&fantasy  0.176419
# 1500                 internationalmovies sci-fi&fantasy  0.174714
# 2855                            action&adventure dramas  0.161394
# 824                     action&adventure sci-fi&fantasy  0.158397
# 3955    tvaction&adventure tvmysteries tvsci-fi&fantasy  0.151947
# 2997                           sci-fi&fantasy thrillers  0.150250
# 5915           crimetvshows tvaction&adventure tvdramas  0.144986
# 4872                 internationalmovies sci-fi&fantasy  0.144518
# 913              action&adventure dramas sci-fi&fantasy  0.143986
# 561                     action&adventure sci-fi&fantasy  0.141220
# 1965                    action&adventure sci-fi&fantasy  0.141220
# 3504                    action&adventure sci-fi&fantasy  0.141220
# 3255           action&adventure comedies sci-fi&fantasy  0.138446
# 1949                    action&adventure sci-fi&fantasy  0.137732
# 5057                    action&adventure sci-fi&fantasy  0.137732
# 5207                    action&adventure sci-fi&fantasy  0.137732
# 2476          dramas internationalmovies sci-fi&fantasy  0.137464
# 4600                                   action&adventure  0.135769
# 518                     action&adventure sci-fi&fantasy  0.134491
# 825                     action&adventure sci-fi&fantasy  0.134491
# 1131                    action&adventure sci-fi&fantasy  0.134491
# 1997                    action&adventure sci-fi&fantasy  0.134491
# 3045                    action&adventure sci-fi&fantasy  0.134491
# 3086                    action&adventure sci-fi&fantasy  0.134491

# %% [markdown]
# ### Using Count Vectorizer to find similar movies based on each actors, directors, genres similarity score

# %% [markdown]
# #### Actors

# %%
cosine_sim_actors = countVectorizer('actors')

# %%
get_recommendations('The Matrix', cosine_sim_actors, 'cast')
# Out:
# /Users/dianaow/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#       index   show_id
# 19                        gasparnoé gasparnoé gasparnoé  0.000000
# 20                     tomo'brien tomo'brien tomo'brien  0.000000
# 21    antoinebardou-jacquet antoinebardou-jacquet an...  0.000000
# 22               mitchdickman mitchdickman mitchdickman  0.000000
# 23               bradanderson bradanderson bradanderson  0.000000
# 24                  austinstark austinstark austinstark  0.000000
# 25               hannahfidell hannahfidell hannahfidell  0.000000

# %% [markdown]
# #### Categories

# %%
cosine_sim_categories = countVectorizer('categories')

# %%
get_recommendations('Stranger', cosine_sim_categories, 'categories')
# Out:
# /Users/dianaow/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#       index   show_id                              title  \
# 821     821  80987077                             Signal
# 843     843  81167047                             Tunnel
# 1121   1121  80198001              Strong Girl Bong-soon
# 1514   1514  80187302                           Stranger
# 1567   1567  81087762                              Abyss
# 1678   1678  80098047                               Last
# 1952   1952  80214772                Bad Guys: Vile City
# 2243   2243  80094387                   A Man Called God
# 2688   2688  80176866                         Man to Man
# 2689   2689  80162114                     My Little Baby
# 3774   3774  80214523                               Live
# 4429   4429  81004280           Memories of the Alhambra
# 4529   4529  80214013                              Black
# 4734   4734  80178427                           Bad Guys
# 5222   5222  81087764                          Possessed
# 103     103  80220715                           Skylines
# 155     155  81020513                   Criminal: France
# 156     156  81020518                  Criminal: Germany
# 158     158  80216172                       Criminal: UK
# 190     190  81144925           When the Camellia Blooms
# 225     225  81003648                           Al Hayba
# 277     277  80217669                            Top Boy
# 285     285  81011508                               Life
# 333     333  81004113                   Age of Rebellion
# 453     453  80220650          YG Future Strategy Office
# 467     467  80242051  Sleepless Society: Bedtime Wishes
# 474     474  81166978                 Bring It On, Ghost
# 476     476  81167029                  Tomorrow with You
# 477     477  81142594                             Tunnel
# 527     527  80221210                        Brotherhood
#
#                                              categories  scores
# 821     crimetvshows internationaltvshows koreantvshows     1.0
# 843     crimetvshows internationaltvshows koreantvshows     1.0
# 1121    crimetvshows internationaltvshows koreantvshows     1.0
# 1514    crimetvshows internationaltvshows koreantvshows     1.0
# 1567    crimetvshows internationaltvshows koreantvshows     1.0
# 1678    crimetvshows internationaltvshows koreantvshows     1.0
# 1952    crimetvshows internationaltvshows koreantvshows     1.0
# 2243    crimetvshows internationaltvshows koreantvshows     1.0
# 2688    crimetvshows internationaltvshows koreantvshows     1.0
# 2689    crimetvshows internationaltvshows koreantvshows     1.0
# 3774    crimetvshows internationaltvshows koreantvshows     1.0
# 4429    crimetvshows internationaltvshows koreantvshows     1.0
# 4529    crimetvshows internationaltvshows koreantvshows     1.0
# 4734    crimetvshows internationaltvshows koreantvshows     1.0
# 5222    crimetvshows internationaltvshows koreantvshows     1.0
# 103          crimetvshows internationaltvshows tvdramas     0.6
# 155          crimetvshows internationaltvshows tvdramas     0.6
# 156          crimetvshows internationaltvshows tvdramas     0.6
# 158    britishtvshows crimetvshows internationaltvshows     0.6
# 190   internationaltvshows koreantvshows romantictvs...     0.6
# 225          crimetvshows internationaltvshows tvdramas     0.6
# 277    britishtvshows crimetvshows internationaltvshows     0.6
# 285         internationaltvshows koreantvshows tvdramas     0.6
# 333          crimetvshows internationaltvshows tvdramas     0.6
# 453       internationaltvshows koreantvshows tvcomedies     0.6
# 467          crimetvshows internationaltvshows tvdramas     0.6
# 474   internationaltvshows koreantvshows romantictvs...     0.6
# 476   internationaltvshows koreantvshows romantictvs...     0.6
# 477          crimetvshows internationaltvshows tvdramas     0.6
# 527          crimetvshows internationaltvshows tvdramas     0.6

# %% [markdown]
# ### Combine each description, actors, directors, genres similarity score to derive a total score

# %%
def improved_recommendations(title):
    df_actors = get_recommendations(title, cosine_sim_actors, 'actors').rename(columns={'scores': 'actor_score'})
    df_directors = get_recommendations(title, cosine_sim_director, 'directors').rename(columns={'scores': 'director_score'})
    df_categories = get_recommendations(title, cosine_sim_categories, 'categories').rename(columns={'scores': 'category_score'})
    df_description = get_recommendations(title, cosine_similarities, 'description').rename(columns={'scores': 'description_score'})
    data_frames = [df_actors, df_directors, df_categories, df_description]
    df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['index', 'title', 'show_id'], how='outer'), data_frames)
    df_merged = df_merged.fillna(0)
    df_merged['scores'] = df_merged['actor_score'] + df_merged['director_score'] + df_merged['category_score']*0.25 + df_merged['description_score'] 
    df_merged = df_merged.sort_values('scores', ascending=False).reset_index(drop=True).head(10)
    
    # extract image url
    for i,row in df_merged.iterrows():
        image = df_photosAll[(df_photosAll['show_id'] == row.show_id)]['url']
        df_merged.loc[i, 'image'] = image
        
    return df_merged

# %%
inception = improved_recommendations('Inception')
# Out:
# /Users/dianaow/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
inception.head(10)
# Out:
#    index   show_id                                  title  \
# 0    335  70024088                                  Brick
# 1   4049  80141928                       Before the Flood
# 2   2696  70202141                                  50/50
# 3   3504  60029363                            Dragonheart
# 4   3524  70131314                              Inception
# 5    276  81023636                              Time Trap
# 6   3084  70114342                        The Book of Eli
# 7   2675  80176756  Dragonheart: Battle for the Heartfire
# 8   2302  70111265                               Hulk Vs.
# 9   1997  80176592                                 Revolt
#
#                                               actors  actor_score directors  \
# 0  josephgordon-levitt josephgordon-levitt noraze...     0.357244         0
# 1                  leonardodicaprio leonardodicaprio     0.340997         0
# 2  josephgordon-levitt josephgordon-levitt sethro...     0.309612         0
# 3  seanconnery seanconnery dennisquaid dennisquai...     0.029348         0
# 4                                                  0     0.000000         0
# 5                                                  0     0.000000         0
# 6                                                  0     0.000000         0
# 7                                                  0     0.000000         0
# 8                                                  0     0.000000         0
# 9                                                  0     0.000000         0
#
#    director_score                                 categories  category_score  \
# 0             0.0                                          0        0.000000
# 1             0.0                                          0        0.000000
# 2             0.0                                          0        0.000000
# 3             0.0            action&adventure sci-fi&fantasy        0.904534
# 4             0.0  action&adventure sci-fi&fantasy thrillers        1.000000
# 5             0.0            action&adventure sci-fi&fantasy        0.904534
# 6             0.0            action&adventure sci-fi&fantasy        0.904534
# 7             0.0            action&adventure sci-fi&fantasy        0.904534
# 8             0.0            action&adventure sci-fi&fantasy        0.904534
# 9             0.0            action&adventure sci-fi&fantasy        0.904534
#
#   description  description_score    scores
# 0           0                0.0  0.357244
# 1           0                0.0  0.340997
# 2           0                0.0  0.309612
# 3           0                0.0  0.255482
# 4           0                0.0  0.250000
# 5           0                0.0  0.226134
# 6           0                0.0  0.226134
# 7           0                0.0  0.226134
# 8           0                0.0  0.226134
# 9           0                0.0  0.226134

# %%
matrix = improved_recommendations('The Matrix')
# Out:
# /Users/dianaow/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
matrix.head(10)
# Out:
#    index   show_id                                  title  \
# 0   1423  60027695                    The Matrix Reloaded
# 1   1424  60031303                 The Matrix Revolutions
# 2   5064  70301367                      Jupiter Ascending
# 3   5131  70248183                            Cloud Atlas
# 4   2675  80176756  Dragonheart: Battle for the Heartfire
# 5   3085  70021661                     The Brothers Grimm
# 6   3084  70114342                        The Book of Eli
# 7   3569  60029154     Terminator 3: Rise of the Machines
# 8   3519  11819467                               Godzilla
# 9   3517  70044594                            Ghost Rider
#
#                                               actors  actor_score  \
# 0  keanureeves keanureeves laurencefishburne laur...     0.683741
# 1  keanureeves keanureeves laurencefishburne laur...     0.675211
# 2                                                  0     0.000000
# 3                                                  0     0.000000
# 4                                                  0     0.000000
# 5                                                  0     0.000000
# 6                                                  0     0.000000
# 7                                                  0     0.000000
# 8                                                  0     0.000000
# 9                                                  0     0.000000
#
#                                            directors  director_score  \
# 0  lillywachowski lanawachowski lillywachowski la...        1.000000
# 1  lillywachowski lanawachowski lillywachowski la...        1.000000
# 2  lanawachowski lillywachowski lanawachowski lil...        0.967742
# 3  lillywachowski lanawachowski tomtykwer lillywa...        0.692763
# 4                                                  0        0.000000
# 5                                                  0        0.000000
# 6                                                  0        0.000000
# 7                                                  0        0.000000
# 8                                                  0        0.000000
# 9                                                  0        0.000000
#
#                         categories  category_score  \
# 0  action&adventure sci-fi&fantasy             1.0
# 1  action&adventure sci-fi&fantasy             1.0
# 2                                0             0.0
# 3                                0             0.0
# 4  action&adventure sci-fi&fantasy             1.0
# 5  action&adventure sci-fi&fantasy             1.0
# 6  action&adventure sci-fi&fantasy             1.0
# 7  action&adventure sci-fi&fantasy             1.0
# 8  action&adventure sci-fi&fantasy             1.0
# 9  action&adventure sci-fi&fantasy             1.0
#
#                                          description  description_score  \
# 0  The crew must protect Zion, the last outpost s...           0.108047
# 1                                                  0           0.000000
# 2                                                  0           0.000000
# 3                                                  0           0.000000
# 4                                                  0           0.000000
# 5                                                  0           0.000000
# 6                                                  0           0.000000
# 7                                                  0           0.000000
# 8                                                  0           0.000000
# 9                                                  0           0.000000
#
#      scores
# 0  2.041787
# 1  1.925211
# 2  0.967742
# 3  0.692763
# 4  0.250000
# 5  0.250000
# 6  0.250000
# 7  0.250000
# 8  0.250000
# 9  0.250000

# %% [markdown]
# ### Extract thumbnails of movie or TV show posters

# %%
def getImagesFromFlixable(show_id):

    URL = 'https://flixable.com/title/' + str(show_id) + '/'
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.findAll("img")
    
    return {'show_id':show_id, 'url': results[0]['data-src']}

# %%
#dict_photos = []
#for i in df[5000:6234].show_id:
    #dict_photos.append(getImagesFromFlixable(i))
#df_photosAll = pd.DataFrame(dict_photos)

# %%
#outfile = open('./data/photo_url_6000.pkl','wb')
#pickle.dump(df_photosAll, outfile)
#outfile.close()
